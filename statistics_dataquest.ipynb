# %%
import pandas as pd
wnba=pd.read_csv("WNBA Stats.csv")
wnba
# Out:
#                  Name Team  Pos  Height  Weight        BMI Birth_Place  \
# 0       Aerial Powers  DAL    F     183    71.0  21.200991          US
# 1         Alana Beard   LA  G/F     185    73.0  21.329438          US
# 2        Alex Bentley  CON    G     170    69.0  23.875433          US
# 3     Alex Montgomery  SAN  G/F     185    84.0  24.543462          US
# 4        Alexis Jones  MIN    G     175    78.0  25.469388          US
# ..                ...  ...  ...     ...     ...        ...         ...
# 138     Tiffany Hayes  ATL    G     178    70.0  22.093170          US
# 139   Tiffany Jackson   LA    F     191    84.0  23.025685          US
# 140  Tiffany Mitchell  IND    G     175    69.0  22.530612          US
# 141      Tina Charles   NY  F/C     193    84.0  22.550941          US
# 142     Yvonne Turner  PHO    G     175    59.0  19.265306          US
#
#               Birthdate  Age         College  ... OREB  DREB  REB  AST  STL  \
# ...

# %%
#print(wnba.head())
#print(wnba.tail())
#wnba.shape
parameter=wnba["Games Played"].max()
sample=wnba["Games Played"].sample(30, random_state=1)
statistic=sample.max()
sampling_error=parameter-statistic

# %%
parameter=wnba["Games Played"].max()
parameter
# Out:
# 32

# %%
#using function in pandas- df.func()
print(wnba["BMI"].mean())
print(wnba["BMI"].median())
print(wnba["BMI"].mode())
# Out:
# 23.091214227746466
# 22.8733141
# 0    21.55102
# 1    23.76641
# dtype: float64

# %%
###Range 
range= wnba[["Height",'Weight', "BMI",'Games Played', 'MIN',
       'FGM', 'FGA', 'FG%', '15:00', '3PA', '3P%', 'FTM', 'FTA', 'FT%', 'OREB',
       'DREB', 'REB', 'AST', 'STL', 'BLK', 'TO', 'PTS', 'DD2', 'TD3']].max() - wnba[["Height",'Weight', "BMI",'Games Played', 'MIN',
       'FGM', 'FGA', 'FG%', '15:00', '3PA', '3P%', 'FTM', 'FTA', 'FT%', 'OREB',
       'DREB', 'REB', 'AST', 'STL', 'BLK', 'TO', 'PTS', 'DD2', 'TD3']].min()
range
# Out:
# Height            41.000000
# Weight            58.000000
# BMI               13.165206
# Games Played      30.000000
# MIN             1006.000000
# FGM              226.000000
# FGA              506.000000
# FG%               85.700000
# 15:00             88.000000
# 3PA              225.000000
# 3P%              100.000000
# FTM              168.000000
# FTA              186.000000
# FT%              100.000000
# OREB             113.000000
# DREB             226.000000
# REB              332.000000
# AST              206.000000
# STL               63.000000
# BLK               64.000000
# TO                85.000000
# PTS              582.000000
# DD2               17.000000
# TD3                1.000000
# dtype: float64

# %%
num_wnba= wnba[["Height",'Weight', "BMI",'Games Played', 'MIN',
       'FGM', 'FGA', 'FG%', '15:00', '3PA', '3P%', 'FTM', 'FTA', 'FT%', 'OREB',
       'DREB', 'REB', 'AST', 'STL', 'BLK', 'TO', 'PTS', 'DD2', 'TD3']]
num_wnba
# Out:
#      Height  Weight        BMI  Games Played  MIN  FGM  FGA   FG%  15:00  3PA  \
# 0       183    71.0  21.200991             8  173   30   85  35.3     12   32
# 1       185    73.0  21.329438            30  947   90  177  50.8      5   18
# 2       170    69.0  23.875433            26  617   82  218  37.6     19   64
# 3       185    84.0  24.543462            31  721   75  195  38.5     21   68
# 4       175    78.0  25.469388            24  137   16   50  32.0      7   20
# ..      ...     ...        ...           ...  ...  ...  ...   ...    ...  ...
# 138     178    70.0  22.093170            29  861  144  331  43.5     43  112
# 139     191    84.0  23.025685            22  127   12   25  48.0      0    1
# 140     175    69.0  22.530612            27  671   83  238  34.9     17   69
# 141     193    84.0  22.550941            29  952  227  509  44.6     18   56
# 142     175    59.0  19.265306            30  356   59  140  42.1     11   47
#
# ...

# %%
#variance count 
num_wnba.var()
# Out:
# Height             75.430415
# Weight            120.914444
# BMI                 4.300195
# Games Played       50.470501
# MIN             84551.449916
# FGM              3148.432582
# FGA             13798.518369
# FG%               102.242392
# 15:00             301.227913
# 3PA              2125.781542
# 3P%               342.700903
# FTM              1350.396927
# FTA              1957.607111
# FT%               350.146217
# OREB              462.648971
# DREB             2476.248596
# REB              4665.190092
# AST              1720.840737
# STL               180.606126
# BLK               156.755245
# TO                462.336748
# PTS             23525.899340
# DD2                 8.411799
# TD3                 0.006993
# dtype: float64

# %%
num_wnba.std()
# Out:
# Height            8.685068
# Weight           10.996110
# BMI               2.073691
# Games Played      7.104259
# MIN             290.777320
# FGM              56.110895
# FGA             117.467095
# FG%              10.111498
# 15:00            17.355919
# 3PA              46.106199
# 3P%              18.512183
# FTM              36.747747
# FTA              44.244854
# FT%              18.712194
# OREB             21.509276
# DREB             49.761919
# REB              68.302197
# AST              41.483017
# STL              13.438978
# BLK              12.520193
# TO               21.502017
# PTS             153.381548
# DD2               2.900310
# TD3               0.083624
# dtype: float64

# %%
#covariance
num_wnba.cov()
# Out:
#                   Height      Weight         BMI  Games Played           MIN  \
# Height         75.430415   73.693887    2.952740     -8.485128   -329.272777
# Weight         73.693887  120.914444   17.152908    -16.721357   -742.636050
# BMI             2.952740   17.152908    4.300195     -2.589082   -126.578481
# Games Played   -8.485128  -16.721357   -2.589082     50.470501   1498.200187
# MIN          -329.272777 -742.636050 -126.578481   1498.200187  84551.449916
# FGM           -20.207771  -91.175857  -20.525527    232.227814  14853.863242
# FGA          -141.700089 -298.339626  -48.948377    515.790555  31646.024574
# FG%            21.222442   23.220627    1.707882      1.581188    649.640884
# 15:00         -48.619078  -65.301468   -6.828769     45.640205   2803.999360
# 3PA          -141.539102 -190.162471  -19.951822    131.579188   7633.441594
# 3P%           -39.530868  -48.257202   -3.561546     22.569167   1542.619113
# ...

# %%
#correlation count
num_wnba.corr()
# Out:
#                 Height    Weight       BMI  Games Played       MIN       FGM  \
# Height        1.000000  0.770489  0.163703     -0.137520 -0.130383 -0.041467
# Weight        0.770489  1.000000  0.752237     -0.214920 -0.233388 -0.148116
# BMI           0.163703  0.752237  1.000000     -0.176460 -0.210939 -0.176812
# Games Played -0.137520 -0.214920 -0.176460      1.000000  0.725255  0.582570
# MIN          -0.130383 -0.233388 -0.210939      0.725255  1.000000  0.910399
# FGM          -0.041467 -0.148116 -0.176812      0.582570  0.910399  1.000000
# FGA          -0.138893 -0.231564 -0.201462      0.618071  0.926494  0.967267
# FG%           0.241661  0.214274  0.083570      0.022011  0.220952  0.319448
# 15:00        -0.322542 -0.341832 -0.189552      0.370153  0.555610  0.518665
# 3PA          -0.353463 -0.374683 -0.208457      0.401707  0.569378  0.508295
# 3P%          -0.245870 -0.237746 -0.093043      0.171609  0.286576  0.268776
# ...

# %%
#skewness and kurtosis
print(num_wnba.skew())
print(num_wnba.kurtosis())
# Out:
# Height          -0.112274
# Weight           0.356322
# BMI              1.040025
# Games Played    -1.486481
# MIN             -0.045340
# FGM              0.711988
# FGA              0.496731
# FG%              1.113671
# 15:00            1.559733
# 3PA              1.270995
# 3P%              0.490246
# FTM              1.295503
# FTA              1.182682
# FT%             -2.389972
# OREB             1.879455
# DREB             1.248483
# REB              1.311881
# AST              1.362470
# STL              0.809025
# BLK              2.420302
# TO               0.515074
# PTS              0.718557
# DD2              3.586333
# TD3             11.958261
# dtype: float64
# Height           -0.866376
# Weight            0.479657
# BMI               2.576344
# Games Played      1.412422
# MIN              -1.253003
# FGM              -0.299329
# FGA              -0.627737
# FG%               6.738000
# 15:00             2.494917
# 3PA               1.505165
# ...

# %%
wnba.describe()
# Out:
#            Height      Weight         BMI         Age  Games Played  \
# count  143.000000  142.000000  142.000000  143.000000    143.000000
# mean   184.566434   78.978873   23.091214   27.076923     24.356643
# std      8.685068   10.996110    2.073691    3.679170      7.104259
# min    165.000000   55.000000   18.390675   21.000000      2.000000
# 25%    176.500000   71.500000   21.785876   24.000000     22.000000
# 50%    185.000000   79.000000   22.873314   27.000000     27.000000
# 75%    191.000000   86.000000   24.180715   30.000000     29.000000
# max    206.000000  113.000000   31.555880   36.000000     32.000000
#
#                MIN         FGM         FGA         FG%       15:00  ...  \
# count   143.000000  143.000000  143.000000  143.000000  143.000000  ...
# mean    496.972028   73.895105  167.622378   42.901399   14.727273  ...
# std     290.777320   56.110895  117.467095   10.111498   17.355919  ...
# ...

# %%
#Quantiles count
num_wnba.quantile(.25)
# Out:
# Height          176.500000
# Weight           71.500000
# BMI              21.785876
# Games Played     22.000000
# MIN             240.000000
# FGM              26.000000
# FGA              66.000000
# FG%              36.950000
# 15:00             0.000000
# 3PA               3.000000
# 3P%               0.000000
# FTM              12.000000
# FTA              16.500000
# FT%              71.150000
# OREB              7.000000
# DREB             25.500000
# REB              34.000000
# AST              11.000000
# STL               7.000000
# BLK               2.000000
# TO               13.500000
# PTS              75.000000
# DD2               0.000000
# TD3               0.000000
# Name: 0.25, dtype: float64

# %%
#IQR, inter quantile count
IQR=num_wnba.quantile(.75)-num_wnba.quantile(.25)
IQR
# Out:
# Height           14.50000
# Weight           14.50000
# BMI               2.39484
# Games Played      7.00000
# MIN             510.00000
# FGM              79.00000
# FGA             178.50000
# FG%              11.60000
# 15:00            22.00000
# 3PA              62.00000
# 3P%              36.15000
# FTM              40.50000
# FTA              49.50000
# FT%              14.70000
# OREB             24.00000
# DREB             58.50000
# REB              82.00000
# AST              55.50000
# STL              20.00000
# BLK              10.00000
# TO               34.50000
# PTS             202.50000
# DD2               1.00000
# TD3               0.00000
# dtype: float64
